# %% [markdown]
# ## Data structures
#  - List Ordered, Changeable, duplicates
#  - Tuple Ordered, Unchangeable, duplicates
#  - Unordered Addable/removable, no duplicates
#  - Dictionary unordered, changeable, no duplicates
#
#
# | List | Tuple | Set | Dictionary |
# | ----------- | ----------- |----------- |----------- |
# | L = [12, "banana", 5.3] | T = (12, "banana", 5.3) |S = {12, "banana", 5.3} |T = {"Val":12, "name":"Ban"} |
# | L[1] | L[2] | X in S | D["Val"] |
# | L = L=["game"] <br> L[2] = "orange" | Immutable <br> T3 = T[1] + T[2] | S.add("new item") <br> S.update({"more","items"}) | D["Val"] = newValue <br> D["newkey"] = "newVale"
# | del L[1] <br> del L | Immutable <br> Del T | S.Remove("banana") <br> del S | del D["Val"] <br> del D |
# |L2 = L.copy() | T2 = T | S2 + S.copy() | D2 = D.copy() |
# |... | ... | ... | ... |

# %%
L = [1,3,4.9,"name",3]
T = (1,3,4.9,"name",3)
S = {1,3,4.9,"name",3}
D = {23:"twothree",'B':43,'C':'CCD'}

# %%
print("The type of L is ", type(L))
print("The type of T is ", type(T))
print("The type of S is ", type(S))
print("The type of D is ", type(D))
# Out:
# The type of L is  <class 'list'>
# The type of T is  <class 'tuple'>
# The type of S is  <class 'set'>
# The type of D is  <class 'dict'>

# %%
print(L[1])
print(T[1])
print(3 in S)
print(D[23])
# Out:
# 3
# 3
# True
# twothree

# %%
print(L)
print(L[1:3])
print(L[::-1])
print(T)
print(T[:3])
# Out:
# [1, 3, 4.9, 'name', 3]
# [3, 4.9]
# [3, 'name', 4.9, 3, 1]
# (1, 3, 4.9, 'name', 3)
# (1, 3, 4.9)

# %%
T2 = T + T
print(T2)
# Out:
# (1, 3, 4.9, 'name', 3, 1, 3, 4.9, 'name', 3)

# %%
S.add(56)
S
# Out:
# {1, 3, 4.9, 56, 'name'}

# %%
S.update({23,"game",1})
S
# Out:
# {1, 23, 3, 4.9, 56, 'game', 'name'}

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'C': 'CCD'}

# %%
D['newKey'] = "newValue"

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'C': 'CCD', 'newKey': 'newValue'}

# %%
D2 = {"y":"YY","z":10}
# cannot add ditciontaries D3 = D+D2
D.update(D2)
D
# Out:
# {23: 'twothree', 'B': 43, 'C': 'CCD', 'newKey': 'newValue', 'y': 'YY', 'z': 10}

# %%
del L[3]
L
# Out:
# [1, 3, 4.9, 3]

# %%
S.remove('game')
S
# Out:
# {1, 23, 3, 4.9, 56, 'name'}

# %%
L2 = L 
print(L2)
# Out:
# [1, 3, 4.9, 3]

# %%
L2[2] = "four point nine"
print(L)
print(L2)
# Out:
# [1, 3, 'four point nine', 3]
# [1, 3, 'four point nine', 3]

# %%
L3 = L.copy()
L3[1] = "three"
print(L3)
print(L)
# Out:
# [1, 'three', 'four point nine', 3]
# [1, 3, 'four point nine', 3]

# %%
print(L)
# Out:
# None

# %%
L.append("Hello")
L
# Out:
# [1, 3, 4.9, 3, 'Hello', 'Hello']

# %%
L = [1,3,'four point nine',3,'how','are',6,'you',6.8]

# %%
help(L.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
L.clear?
# Out:
# Signature: L.clear()
# Docstring: Remove all items from list.
# Type:      builtin_function_or_method

# %%
L.pop?
# Out:
# Signature: L.pop(index=-1, /)
# Docstring:
# Remove and return item at index (default last).
#
# Raises IndexError if list is empty or index is out of range.
# Type:      builtin_function_or_method

# %%
L.reverse()
print(L)
# Out:
# [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8]

# %%
D.items()
# Out:
# dict_items([(23, 'twothree'), ('B', 43), ('C', 'CCD'), ('newKey', 'newValue'), ('y', 'YY'), ('z', 10)])

# %%
D2 = {'A':L, 'B':T,'C':S,'D':D}
print(D2)
# Out:
# {'A': [1, 3, 'four point nine', 3, 'how', 'are', 6, 'you', 6.8], 'B': (1, 3, 4.9, 'name', 3), 'C': {1, 3, 4.9, 'name', 23, 56}, 'D': {23: 'twothree', 'B': 43, 'C': 'CCD', 'newKey': 'newValue', 'y': 'YY', 'z': 10}}

# %%
D2['A'][3]
# Out:
# 3

# %%
K = D2['D']

# %%
K
# Out:
# {23: 'twothree', 'B': 43, 'C': 'CCD', 'newKey': 'newValue', 'y': 'YY', 'z': 10}

# %%
for x in K: 
    print(x,K[x])
# Out:
# 23 twothree
# B 43
# C CCD
# newKey newValue
# y YY
# z 10

# %%
L3 = [L,T,D,23,"game"]
print(type(L3[2]))
# Out:
# <class 'dict'>

# %%
L3 = [x**2 for x in range(10)]

# %%
L3
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
S3 = {x**2 for x in range(2, 20,3)}
print(S3)
# Out:
# {64, 121, 289, 196, 4, 25}

# %%
"""
Example: average the grades of students through multiple classes
"""

def getDataFromUser():
    D = {}
    while True: 
        studentId = input("Enter Student ID: ")
        marksList = input("Enter the marks by comma seperated values: ")
        moreStudents = input("Enter \"no\" to quit insertion: ")
        if studentId in D: 
            print(studentId, "is already inserted")
        else: 
            D[studentId] = marksList.split(",")
        if moreStudents.lower() == "no": 
            return D

# %%
studentData = getDataFromUser()
# Out:
# Enter Student ID:  12
# Enter the marks by comma seperated values:  56,45,13
# Enter "no" to quit insertion:  asdf
# Enter Student ID:  45
# Enter the marks by comma seperated values:  44,55,77,4
# Enter "no" to quit insertion:  asdf
# Enter Student ID:  12
# Enter the marks by comma seperated values:  45,45
# Enter "no" to quit insertion:  asdf
# 12 is already inserted
# Enter Student ID:  23
# Enter the marks by comma seperated values:  45,45
# Enter "no" to quit insertion:  no

# %%
studentData
# Out:
# {'12': ['56', '45', '13'], '45': ['44', '55', '77', '4'], '23': ['45', '45']}

# %%
def getAvgMarks(D):
    avgMarks = {}
    for x in D:
        L = D[x]
        s=0
        for marks in L: 
            s+=int(marks)
        avgMarks[x] = s/len(L)
    return avgMarks

# %%
avgM = getAvgMarks(studentData)

# %%
for x in avgM:
    print( "Student :",x,"got avg Marks as: ", avgM[x])
# Out:
# Student : 12 got avg Marks as:  38.0
# Student : 45 got avg Marks as:  45.0
# Student : 23 got avg Marks as:  45.0
